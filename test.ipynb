# %%
import sys
print(sys.executable)
print(sys.version)

import anthropic, fastapi, pandas, matplotlib
print("anthropic:", anthropic.__version__)
print("fastapi:", fastapi.__version__)
print("pandas:", pandas.__version__)
print("all imports OK")
# Out:
# /home/alvincrespo/.pyenv/versions/dl-ai-labs/bin/python
# 3.13.5 (main, Aug  4 2025, 14:34:20) [GCC 13.3.0]
# anthropic: 1.4.0
# fastapi: 0.141.1
# pandas: 3.0.5
# all imports OK
